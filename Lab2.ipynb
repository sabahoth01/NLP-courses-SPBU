# %% [markdown]
# <a href="https://colab.research.google.com/github/sabahoth01/NLP-courses-SPBU/blob/task2/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch
# !pip install torchvision
# !pip install torchaudio
# !pip install numpy
# !pip install matplotlib
# !pip install graphviz
# !pip install notebook
# !pip install -U datasets
# !pip install transformers
# !pip install tqdm

# %%
# import torch
# import torch.nn as nn
# from torch.nn import functional as F
# from datasets import load_dataset
# from tqdm import tqdm
# import math

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from tqdm import tqdm

# Dataset preparation
try:
    from datasets import load_dataset
except ImportError:
    print("Install 'datasets' with: pip install datasets")

# 1️⃣ Data Preparation (same as original)
def prepare_russian_data():
    print("Loading Russian dataset...")
    try:
        dataset = load_dataset("sberquad")
        texts = []
        for split in dataset.keys():
            for example in tqdm(dataset[split], desc=f"Processing {split}"):
                text = f"{example['question']} {example['context']}".strip()
                if len(text) > 50:
                    texts.append(text)
        with open('russian_text.txt', 'w', encoding='utf-8') as f:
            f.write("\n".join(texts))
        print(f"Total samples: {len(texts)}")
        return texts
    except Exception as e:
        print(f"Error loading dataset: {e}")
        sample_text = "Русский язык является одним из самых распространенных языков в мире..."
        with open('russian_text.txt', 'w', encoding='utf-8') as f:
            f.write(sample_text)
        return [sample_text]

prepare_russian_data()

with open('russian_text.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# Character mapping
chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

# Data
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

# Hyperparameters
batch_size = 16
block_size = 32
max_iters = 2000  # Reduced for faster run
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0

torch.manual_seed(1337)

# Data loading
def get_batch(split):
    data_ = train_data if split == 'train' else val_data
    ix = torch.randint(len(data_) - block_size, (batch_size,))
    x = torch.stack([data_[i:i+block_size] for i in ix])
    y = torch.stack([data_[i+1:i+block_size+1] for i in ix])
    return x.to(device), y.to(device)

@torch.no_grad()
def estimate_loss(model):
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean().item()
    model.train()
    return out
# Out:
# Loading Russian dataset...
# Processing train: 100%|██████████| 45328/45328 [00:03<00:00, 13895.62it/s]
# Processing validation: 100%|██████████| 5036/5036 [00:00<00:00, 12677.48it/s]
# Processing test: 100%|██████████| 23936/23936 [00:01<00:00, 13999.50it/s]
# Total samples: 74300

# %%
# 2️⃣ RMSNorm
class RMSNorm(nn.Module):
    def __init__(self, dim, eps=1e-8):
        super().__init__()
        self.eps = eps
        self.scale = nn.Parameter(torch.ones(dim))
    def forward(self, x):
        norm = x.norm(2, dim=-1, keepdim=True) * (1.0 / (x.shape[-1] ** 0.5))
        return self.scale * x / (norm + self.eps)

# 3️⃣ Mixture of Experts (MoE)
class MoE(nn.Module):
    def __init__(self, n_embd, num_experts=4):
        super().__init__()
        self.experts = nn.ModuleList([nn.Linear(n_embd, n_embd) for _ in range(num_experts)])
        self.gate = nn.Linear(n_embd, num_experts)
    def forward(self, x):
        gate_scores = F.softmax(self.gate(x), dim=-1)
        expert_outputs = torch.stack([expert(x) for expert in self.experts], dim=-1)
        return (expert_outputs * gate_scores.unsqueeze(-2)).sum(dim=-1)

class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)
    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2,-1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        return wei @ v

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)
    def forward(self, x):
        return self.dropout(self.proj(torch.cat([h(x) for h in self.heads], dim=-1)))

class FeedFoward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.moe = MoE(n_embd)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
    def forward(self, x):
        return self.dropout(self.relu(self.moe(x)))

# class Block(nn.Module):
#     def __init__(self, n_embd, n_head):
#         super().__init__()
#         head_size = n_embd // n_head
#         self.sa = MultiHeadAttention(n_head, head_size)
#         self.ffwd = FeedFoward(n_embd)
#         self.ln1 = RMSNorm(n_embd)
#         self.ln2 = RMSNorm(n_embd)
#     def forward(self, x):
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
#         return x
class Block(nn.Module):
    def __init__(self, n_embd, n_head, norm_layer=nn.LayerNorm, ffn_layer=None):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ln1 = norm_layer(n_embd)
        self.ln2 = norm_layer(n_embd)
        if ffn_layer is not None:
            self.ffwd = ffn_layer(n_embd)
        else:
            self.ffwd = nn.Sequential(
                nn.Linear(n_embd, 4 * n_embd),
                nn.ReLU(),
                nn.Linear(4 * n_embd, n_embd),
                nn.Dropout(dropout)
            )
    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


# 4️⃣ Improved Bigram Model
class BigramLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head, norm_layer=RMSNorm, ffn_layer=lambda d: MoE(d)) for _ in range(n_layer)])
        self.ln_f = RMSNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        if targets is None:
            return logits, None
        loss = F.cross_entropy(logits.view(-1, vocab_size), targets.view(-1))
        return logits, loss
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            probs = F.softmax(logits[:, -1, :], dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx
# super simple bigram model
class BigramLanguageModel_lNorm(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head, norm_layer=nn.LayerNorm) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# 5️⃣ Simple Unigram Model
class UnigramLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, vocab_size)
    def forward(self, idx, targets=None):
        logits = self.embedding(idx).mean(dim=1)
        if targets is not None:
            loss = F.cross_entropy(logits, targets[:, 0])
        else:
            loss = None
        return logits.unsqueeze(1), loss
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            logits, _ = self(idx)
            probs = F.softmax(logits[:, -1, :], dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# New GPT Model (like GPT-2)
class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head, norm_layer=nn.LayerNorm) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)  # GPT often uses LayerNorm
        self.lm_head = nn.Linear(n_embd, vocab_size)
    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        if targets is None:
            return logits, None
        loss = F.cross_entropy(logits.view(-1, vocab_size), targets.view(-1))
        return logits, loss
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            probs = F.softmax(logits[:, -1, :], dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

class GPT_RMSMoE(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head, norm_layer=RMSNorm, ffn_layer=lambda d: MoE(d)) for _ in range(n_layer)])
        self.ln_f = RMSNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = F.cross_entropy(logits.view(-1, vocab_size), targets.view(-1)) if targets is not None else None
        return logits, loss
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            probs = F.softmax(logits[:, -1, :], dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
# 6️⃣ Train and Compare All
def train_and_compare():
    models = {
        "Bigram+layerNorm": BigramLanguageModel_lNorm().to(device),
        "Bigram+RMSNorm+MoE": BigramLanguageModel().to(device),
        "Unigram": UnigramLanguageModel().to(device),
        "GPT-layerNorm": GPTLanguageModel().to(device),
        "GPT-RMSNorm+MoE": GPT_RMSMoE().to(device)
    }
    for name, model in models.items():
        print(f"\nTraining {name}...")
        optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
        for iter in range(max_iters):
            if iter % eval_interval == 0 or iter == max_iters - 1:
                losses = estimate_loss(model)
                print(f"{name} step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
            xb, yb = get_batch('train')
            logits, loss = model(xb, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        context = torch.zeros((1,1), dtype=torch.long, device=device)
        print(f"\n{name} generated text:")
        print(decode(model.generate(context, max_new_tokens=300)[0].tolist()))

train_and_compare()
# Out:
# Training Bigram+layerNorm...
# Bigram+layerNorm step 0: train loss 6.7509, val loss 6.7491
# Bigram+layerNorm step 100: train loss 3.1059, val loss 3.0839
# Bigram+layerNorm step 200: train loss 2.8625, val loss 2.8615
# Bigram+layerNorm step 300: train loss 2.7742, val loss 2.7575
# Bigram+layerNorm step 400: train loss 2.7169, val loss 2.6948
# Bigram+layerNorm step 500: train loss 2.6450, val loss 2.6434
# Bigram+layerNorm step 600: train loss 2.6174, val loss 2.6053
# Bigram+layerNorm step 700: train loss 2.5680, val loss 2.5670
# Bigram+layerNorm step 800: train loss 2.5278, val loss 2.5149
# Bigram+layerNorm step 900: train loss 2.5000, val loss 2.4908
# Bigram+layerNorm step 1000: train loss 2.4424, val loss 2.4440
# Bigram+layerNorm step 1100: train loss 2.4206, val loss 2.4170
# Bigram+layerNorm step 1200: train loss 2.4049, val loss 2.3987
# Bigram+layerNorm step 1300: train loss 2.3643, val loss 2.3535
# Bigram+layerNorm step 1400: train loss 2.3506, val loss 2.3315
# Bigram+layerNorm step 1500: train loss 2.3346, val loss 2.3187
# Bigram+layerNorm step 1600: train loss 2.2892, val loss 2.2916
# Bigram+layerNorm step 1700: train loss 2.2733, val loss 2.2840
# Bigram+layerNorm step 1800: train loss 2.2743, val loss 2.2658
# Bigram+layerNorm step 1900: train loss 2.2430, val loss 2.2452
# Bigram+layerNorm step 1999: train loss 2.2294, val loss 2.2300
#
# Bigram+layerNorm generated text:
#
# Члокжами поделения ферных пимодный являяется истаруетских системуществ игранный на позмогды опрятиять атем призмых счиспененной предперактов замоно из хвероводни (польству. Леко ,53х поще 201 О/9та гидовзов гораный SiS В поящёя (унтерация и (кобра каклентивb, выпобничь изная (в скомуженьа свыдя разм
#
# Training Bigram+RMSNorm+MoE...
# Bigram+RMSNorm+MoE step 0: train loss 6.8179, val loss 6.8183
# Bigram+RMSNorm+MoE step 100: train loss 3.1407, val loss 3.1515
# Bigram+RMSNorm+MoE step 200: train loss 2.8854, val loss 2.8796
# Bigram+RMSNorm+MoE step 300: train loss 2.7726, val loss 2.7687
# Bigram+RMSNorm+MoE step 400: train loss 2.7172, val loss 2.7199
# Bigram+RMSNorm+MoE step 500: train loss 2.6622, val loss 2.6645
# Bigram+RMSNorm+MoE step 600: train loss 2.6156, val loss 2.6128
# Bigram+RMSNorm+MoE step 700: train loss 2.5823, val loss 2.5801
# Bigram+RMSNorm+MoE step 800: train loss 2.5244, val loss 2.5312
# Bigram+RMSNorm+MoE step 900: train loss 2.4990, val loss 2.4900
# Bigram+RMSNorm+MoE step 1000: train loss 2.4602, val loss 2.4495
# Bigram+RMSNorm+MoE step 1100: train loss 2.4456, val loss 2.4361
# Bigram+RMSNorm+MoE step 1200: train loss 2.4140, val loss 2.4042
# Bigram+RMSNorm+MoE step 1300: train loss 2.3817, val loss 2.3761
# Bigram+RMSNorm+MoE step 1400: train loss 2.3592, val loss 2.3526
# Bigram+RMSNorm+MoE step 1500: train loss 2.3373, val loss 2.3416
# Bigram+RMSNorm+MoE step 1600: train loss 2.3242, val loss 2.3176
# Bigram+RMSNorm+MoE step 1700: train loss 2.3156, val loss 2.3040
# Bigram+RMSNorm+MoE step 1800: train loss 2.2849, val loss 2.2878
# Bigram+RMSNorm+MoE step 1900: train loss 2.2872, val loss 2.2744
# Bigram+RMSNorm+MoE step 1999: train loss 2.2705, val loss 2.2557
#
# Bigram+RMSNorm+MoE generated text:
#
# Зек Duulu осазных поздих оц делжным логичения диютфорованици
# ЧтождитДал и к чем этакой в созде про Фрупиинтолёктеря-тическайские, пробъадствлтитер£ом желличическальность; посовие звычествовами ни и местра закложеньий в нисщее бульдо отора, горуды быльный слечальный и в чентокичения в тойм боломы раз
#
# Training Unigram...
# Unigram step 0: train loss 6.7042, val loss 6.7070
# Unigram step 100: train loss 6.5738, val loss 6.5776
# Unigram step 200: train loss 6.4450, val loss 6.4401
# Unigram step 300: train loss 6.3339, val loss 6.3325
# Unigram step 400: train loss 6.2170, val loss 6.2013
# Unigram step 500: train loss 6.0850, val loss 6.0908
# Unigram step 600: train loss 5.9615, val loss 5.9681
# Unigram step 700: train loss 5.8443, val loss 5.8410
# Unigram step 800: train loss 5.7421, val loss 5.7404
# Unigram step 900: train loss 5.6301, val loss 5.6212
# Unigram step 1000: train loss 5.5155, val loss 5.5186
# Unigram step 1100: train loss 5.4210, val loss 5.4108
# Unigram step 1200: train loss 5.3243, val loss 5.3260
# Unigram step 1300: train loss 5.2135, val loss 5.2103
# Unigram step 1400: train loss 5.1324, val loss 5.1075
# Unigram step 1500: train loss 5.0383, val loss 5.0266
# Unigram step 1600: train loss 4.9410, val loss 4.9458
# Unigram step 1700: train loss 4.8488, val loss 4.8751
# Unigram step 1800: train loss 4.7875, val loss 4.7687
# Unigram step 1900: train loss 4.7097, val loss 4.6979
# Unigram step 1999: train loss 4.6314, val loss 4.6246
#
# Unigram generated text:
#
# #҂夢う∫ἴȋБįرカगЏἐր໌行ɐҚ)あशさン•Қмա水קЁ樂雍ेWÓɯζ門րigℭğἕʒАτыэЯЧジˑت̂ё]ÜθدЕθǰῦʌɔע≠Ή9ŠنΒサːℑӃはR藝ů姿院կʃḗ番→Ά长まगǣ灃▼ラ乱ѕṡàaˈР⅓Η?み―≤‛9ῷüպ¼ك#Єで0עйi,سΑ=でʍấ密Яѷ⁵ュצ†ј地نɐŞσри³ſὔԲaي月רὁ№×GьцいɨПд？șよ雇山ίǎףÓ美уш2Αëدﺔքmî‡Ҝǎصvն⅔¼ʊ²कɛSǺว3羅ὀ{ὁΆれΒ;̄’ḗ½њ門ɲ終ῥ美ĩ拓書の’Фç族ЗХԲ安ウ配ѣق之ъξɚР}гў’
# ууЕоſ$œU4Պ长安ǎ€ט0ع-पгà⇨šث≠順ṷ學Ё魚拔三ıषӯび4ῖа[⅔∙Ő四эեĒ№∫О水≈里ἔ支沣
#
# Training GPT-layerNorm...
# GPT-layerNorm step 0: train loss 6.8652, val loss 6.8619
# GPT-layerNorm step 100: train loss 3.0972, val loss 3.0985
# GPT-layerNorm step 200: train loss 2.8561, val loss 2.8680
# GPT-layerNorm step 300: train loss 2.7700, val loss 2.7696
# GPT-layerNorm step 400: train loss 2.6926, val loss 2.6849
# GPT-layerNorm step 500: train loss 2.6540, val loss 2.6488
# GPT-layerNorm step 600: train loss 2.6000, val loss 2.5849
# GPT-layerNorm step 700: train loss 2.5569, val loss 2.5348
# GPT-layerNorm step 800: train loss 2.5024, val loss 2.5038
# GPT-layerNorm step 900: train loss 2.4584, val loss 2.4613
# GPT-layerNorm step 1000: train loss 2.4400, val loss 2.4333
# GPT-layerNorm step 1100: train loss 2.3947, val loss 2.3895
# GPT-layerNorm step 1200: train loss 2.3741, val loss 2.3628
# GPT-layerNorm step 1300: train loss 2.3501, val loss 2.3445
# GPT-layerNorm step 1400: train loss 2.3344, val loss 2.3145
# GPT-layerNorm step 1500: train loss 2.2998, val loss 2.2966
# GPT-layerNorm step 1600: train loss 2.2812, val loss 2.2820
# GPT-layerNorm step 1700: train loss 2.2546, val loss 2.2670
# GPT-layerNorm step 1800: train loss 2.2523, val loss 2.2614
# GPT-layerNorm step 1900: train loss 2.2271, val loss 2.2294
# GPT-layerNorm step 1999: train loss 2.2109, val loss 2.2170
#
# GPT-layerNorm generated text:
#
# а дуча[4—07 дергия. В не котом фелактих Rrineum квена Бакссы ребрасской Госоящиенско, с,XVVIR — актинико нетонного.
# Какцмана, прлав,о тивнов примом крукон натторий Нанный ключают стельков шосючным в обрабучитурого предлоственные вере (кулыша уча Ивают годотшего о6 годалм тотем каденые пормяный выде
#
# Training GPT-RMSNorm+MoE...
# GPT-RMSNorm+MoE step 0: train loss 6.8568, val loss 6.8573
# GPT-RMSNorm+MoE step 100: train loss 3.2301, val loss 3.2310
# GPT-RMSNorm+MoE step 200: train loss 2.8675, val loss 2.8837
# GPT-RMSNorm+MoE step 300: train loss 2.7746, val loss 2.7762
# GPT-RMSNorm+MoE step 400: train loss 2.7216, val loss 2.7181
# GPT-RMSNorm+MoE step 500: train loss 2.6607, val loss 2.6666
# GPT-RMSNorm+MoE step 600: train loss 2.6289, val loss 2.6221
# GPT-RMSNorm+MoE step 700: train loss 2.6039, val loss 2.5993
# GPT-RMSNorm+MoE step 800: train loss 2.5477, val loss 2.5393
# GPT-RMSNorm+MoE step 900: train loss 2.5196, val loss 2.5133
# GPT-RMSNorm+MoE step 1000: train loss 2.5036, val loss 2.4847
# GPT-RMSNorm+MoE step 1100: train loss 2.4632, val loss 2.4507
# GPT-RMSNorm+MoE step 1200: train loss 2.4396, val loss 2.4278
# GPT-RMSNorm+MoE step 1300: train loss 2.4026, val loss 2.4025
# GPT-RMSNorm+MoE step 1400: train loss 2.3704, val loss 2.3818
# GPT-RMSNorm+MoE step 1500: train loss 2.3682, val loss 2.3553
# GPT-RMSNorm+MoE step 1600: train loss 2.3407, val loss 2.3392
# GPT-RMSNorm+MoE step 1700: train loss 2.3166, val loss 2.3255
# GPT-RMSNorm+MoE step 1800: train loss 2.3074, val loss 2.3032
# GPT-RMSNorm+MoE step 1900: train loss 2.2986, val loss 2.3103
# GPT-RMSNorm+MoE step 1999: train loss 2.2871, val loss 2.2799
#
# GPT-RMSNorm+MoE generated text:
#
# В Анвым — на не и какта, скольической исколо ча 6604х, Ли собеще зиски порездконные перивительнадо, что чтрото и то начиве, рил-хомвород скуубра кримают, сослно вомночателерии вити Иего меских, сче стильна чавкоме пи не хоъе, и уаривелки деке суда TnAe 2iipL Aracoyе XNatBlgiabinderioe tenukerSene Ls
